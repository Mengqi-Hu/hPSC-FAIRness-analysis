# %%
# set up
from google.colab import drive
drive.mount('/content/drive')

# %run '/content/drive/My Drive/hPSC-FAIRness Analysis/scripts/setup_drive.py'

root_dir, data_dir, processed_dir, results_dir = setup_drive()
# Out:
# Mounted at /content/drive
# Mounted at /content/drive
# Setting up root directory with name: 'hPSC-FAIRness Analysis'
# Root directory path: '/content/drive/My Drive/hPSC-FAIRness Analysis'

# %%
# Load hPSCs expansion data
df = pd.read_excel(os.path.join(processed_dir,'Cello_expansion.xlsx'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21674 entries, 0 to 21673
# Data columns (total 41 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   AC                         21674 non-null  object
#  1   ID                         21674 non-null  object
#  2   SY                         15411 non-null  object
#  3   DR                         21627 non-null  object
#  4   RX                         11675 non-null  object
#  5   CC                         21653 non-null  object
#  6   OX                         21674 non-null  object
#  7   HI                         5341 non-null   object
#  8   CA                         21674 non-null  object
#  9   DT                         21674 non-null  object
#  10  WW                         2144 non-null   object
#  11  SX                         20936 non-null  object
#  12  AG                         20178 non-null  object
# ...

# %%
counts = df['DI'].value_counts()
print(counts)

#counts.to_excel(os.path.join(processed_dir, 'Disease.xlsx'), index=True)
# Out:
# DI
# NCIt; C26845; Parkinson's disease                                                                                                                                                                                           389
# ['NCIt; C84673; Dilated cardiomyopathy', 'ORDO; Orphanet_217604; Dilated cardiomyopathy']                                                                                                                                   352
# NCIt; C2866; Alzheimer's disease                                                                                                                                                                                            329
# ['NCIt; C35716; Idiopathic pulmonary fibrosis', 'ORDO; Orphanet_2032; Idiopathic pulmonary fibrosis']                                                                                                                       210
# ...

# %%
df['CC_Population'].fillna('Unknown', inplace=True)

counts = df['CC_Population'].value_counts()
print(counts)
#counts.to_excel(os.path.join(processed_dir, 'Population.xlsx'), index=True)
# Out:
# CC_Population
# Unknown                                       11933
# Caucasian                                      4798
# Japanese                                       1089
# Caucasian; British                              581
# Chinese; Han                                    449
#                                               ...
# South American (Brazil, Guyana, Venezuela)        1
# Native South American and Hispanic                1
# Caucasian; Dutch/Spanish                          1
# Cuban                                             1
# Native Central American; Pima                     1
# Name: count, Length: 148, dtype: int64
# <ipython-input-4-b7bafd4882c7>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df = pd.read_excel(os.path.join(processed_dir,'Population.xlsx'))

# %% [markdown]
# ChatGPT helped with finding contient:the logic is 'ok I have a count table with one collumn 'CC_Population' as ethnicity information and another column 'Count' for the number for each ethnicity group. Now I want to find use the geographical group instead (continents, such as Asia, America, Oceania, Africa and Europe) according to 'CC_Population'. If the ethnicity belong to a specifc continent, assign the name of the 5 continent as I mentioned. The ethnicity sometimes group down to specific group and seperated by ';' such as 'African; Angolan', Please help just to find the continent the subgroup 'Angolan' belong. Sometimes, there is a mixed group seperated by 'and' such as 'African American and Chinese', you need to check if the terms combined with 'and' all belongs to one continent, if so, give me the continent, if not, labeled as 'Mixed'.
# I will give you a list of all ethnicity group, could you give my a dictionary (python) that show me which is for which contient?'

# %%
ethnicity_to_continent = {
    "African": "Africa",
    "African; Angolan": "Africa",
    "African; Somali": "Africa",
    "African; Sudanese": "Africa",
    "African; Yoruba in Ibadan, Nigeria (YRI)": "Africa",
    "Cape Verdian": "Africa",
    "Egyptian": "Africa",
    "Jewish; Libyan": "Africa",
    "Lybian": "Africa",
    "Moroccan": "Africa",
    "Tunisian": "Africa",
    "Aboriginal Australian": "Oceania",
    "Pacific": "Oceania",
    "Afghan": "Asia",
    "Afghanistan; Persian": "Asia",
    "Arab": "Asia",
    "Arab; Qatari": "Asia",
    "Asian": "Asia",
    "Bahraini": "Asia",
    "Bangladeshi": "Asia",
    "Bedouin": "Asia",
    "Bengali": "Asia",
    "Caucasian; Armenian": "Asia",
    "Caucasian; Siberian": "Asia",
    "Chinese": "Asia",
    "Chinese; Han": "Asia",
    "Chinese; Malaysian": "Asia",
    "Chinese; Singaporian": "Asia",
    "Chinese; Taiwan": "Asia",
    "Chinese/Asian ethnic group: Hui": "Asia",
    "Chinese/Asian ethnic group: Uyghur": "Asia",
    "East Asian": "Asia",
    "East Indian": "Asia",
    "Indian": "Asia",
    "Iranian": "Asia",
    "Iranian; Persian": "Asia",
    "Iraqi": "Asia",
    "Israeli": "Asia",
    "Japanese": "Asia",
    "Japanese and Korean": "Asia",
    "Jordanian": "Asia",
    "Kazakh": "Asia",
    "Korean": "Asia",
    "Lebanese": "Asia",
    "Middle Eastern": "Asia",
    "Mongolian": "Asia",
    "Nepali": "Asia",
    "Pakistani": "Asia",
    "Palestinian": "Asia",
    "Ryukyuan": "Asia",
    "Saudi Arabian": "Asia",
    "South Asian": "Asia",
    "Southeast Asian": "Asia",
    "Southeast Asian; Burmese": "Asia",
    "Southeast Asian; Cambodian": "Asia",
    "Southeast Asian; Filipino": "Asia",
    "Southeast Asian; Thai": "Asia",
    "Southeast Asian; Vietnamese": "Asia",
    "Turkish": "Asia",
    "Jewish; Yemenite": "Asia",
    "African American": "America",
    "African American and Caucasian": "America",
    "African American and Chinese": "America",
    "African and Hispanic": "Mixed",
    "African and Korean": "Mixed",
    "Afro-Brazilian": "Mixed",
    "Asian and Caucasian": "Mixed",
    "Asian and Latino": "Mixed",
    "Black or African American": "Mixed",
    "Caribbean; Haitian and Caucasian": "Mixed",
    "Caucasian and Asian": "Mixed",
    "Caucasian and Chinese": "Mixed",
    "Caucasian and Cuban": "Mixed",
    "Caucasian and Indian": "Mixed",
    "Caucasian and Japanese": "Mixed",
    "Caucasian and Latino": "Mixed",
    "Caucasian and Native American": "Mixed",
    "Caucasian and Native North American": "Mixed",
    "Caucasian and Native North American; Alaskan": "Mixed",
    "Caucasian and South Asian": "Mixed",
    "Caucasian, Japanese and Southeast Asian; Filipino": "Mixed",
    "Caucasian, Mexican and Indian": "Mixed",
    "Caucasian; British/Italian and Jewish; Ashkenazi": "Mixed",
    "Caucasian; Dutch/Spanish": "Mixed",
    "Caucasian; French and Chinese": "Mixed",
    "Caucasian; Italian and Jewish; Ashkenazi": "Mixed",
    "Caucasian; Romanian and Indian": "Mixed",
    "Hispanic and Caucasian": "Mixed",
    "Hispanic and Native North American": "Mixed",
    "Jewish": "Mixed",
    "Jewish and Caucasian; Scandinavian": "Mixed",
    "Jewish; Ashkenazi": "Mixed",
    "Kurdistani and Tunisian": "Mixed",
    "Latino and Native American": "Mixed",
    "Native South American and Hispanic": "Mixed",
    "Brazilian": "South America",
    "Chilean": "South America",
    "Hispanic": "South America",
    "Latino": "South America",
    "Latino or Hispanic": "South America",
    "Latino or Hispanic; Dominican": "South America",
    "South American (Brazil, Guyana, Venezuela)": "South America",
    "Caribbean": "North America",
    "Caribbean; Haitian": "North America",
    "Caucasian; Canadian Dariusleut Hutterite": "North America",
    "Cuban": "North America",
    "Mexican": "North America",
    "Native American": "North America",
    "Native Central American; Pima": "North America",
    "Native North American": "North America",
    "Native North American; Alaskan": "North America",
    "Native North American; Cherokee": "North America",
    "Puerto Rican": "North America",
    "Caucasian": "Europe",
    "Caucasian, not Hispanic": "Europe",
    "Caucasian; Albanian": "Europe",
    "Caucasian; Amish": "Europe",
    "Caucasian; Austrian": "Europe",
    "Caucasian; Belgian": "Europe",
    "Caucasian; British": "Europe",
    "Caucasian; Bulgarian": "Europe",
    "Caucasian; Czechoslovakian": "Europe",
    "Caucasian; Danish": "Europe",
    "Caucasian; Dutch": "Europe",
    "Caucasian; English": "Europe",
    "Caucasian; Finnish": "Europe",
    "Caucasian; French": "Europe",
    "Caucasian; French/Italian": "Europe",
    "Caucasian; German": "Europe",
    "Caucasian; German/Irish": "Europe",
    "Caucasian; German/Swedish": "Europe",
    "Caucasian; Greek": "Europe",
    "Caucasian; Greek-Cypriot": "Europe",
    "Caucasian; Irish": "Europe",
    "Caucasian; Irish/Italian": "Europe",
    "Caucasian; Italian": "Europe",
    "Caucasian; Mennonite": "Europe",
    "Caucasian; Non-hispanic white": "Europe",
    "Caucasian; Norwegian": "Europe",
    "Caucasian; Polish": "Europe",
    "Caucasian; Portuguese": "Europe",
    "Caucasian; Romani": "Europe",
    "Caucasian; Russian": "Europe",
    "Caucasian; Sardinian": "Europe",
    "Caucasian; Scandinavian": "Europe",
    "Caucasian; Scottish": "Europe",
    "Caucasian; Spanish": "Europe",
    "Unknown": "Unknown"
}

# %%
# Map geographical groups
df['Geographical_Group'] = df['CC_Population'].map(ethnicity_to_continent)

# Group by geographical group and sum the counts
count_table = df.groupby('Geographical_Group')['count'].sum().reset_index().sort_values(by='count', ascending=False)

print(count_table)
# Out:
#   Geographical_Group  count
# 7            Unknown  11933
# 2             Europe   5980
# 1               Asia   2782
# 3              Mixed    517
# 6      South America    256
# 0             Africa    150
# 4      North America     41
# 5            Oceania     15

# %%
ethnicity_to_category = {
    "African American and Caucasian": "Mixed",
    "African American and Chinese": "Mixed",
    "African and Hispanic": "Mixed",
    "African and Korean": "Mixed",
    "Asian and Caucasian": "Mixed",
    "Asian and Latino": "Mixed",
    "Caucasian and Asian": "Mixed",
    "Caucasian and Chinese": "Mixed",
    "Caucasian and Cuban": "Mixed",
    "Caucasian and Indian": "Mixed",
    "Caucasian and Japanese": "Mixed",
    "Caucasian and Latino": "Mixed",
    "Caucasian and Native American": "Mixed",
    "Caucasian and Native North American": "Mixed",
    "Caucasian and Native North American; Alaskan": "Mixed",
    "Caucasian and South Asian": "Mixed",
    "Caucasian, Japanese and Southeast Asian; Filipino": "Mixed",
    "Caucasian, Mexican and Indian": "Mixed",
    "Caucasian; British/Italian and Jewish; Ashkenazi": "White", # check
    "Caucasian; Dutch/Spanish": "White", # check
    "Caucasian; French and Chinese": "Mixed",
    "Caucasian; Italian and Jewish; Ashkenazi": "White", # check
    "Caucasian; Romanian and Indian": "Mixed",
    "Hispanic and Caucasian": "Mixed",
    "Hispanic and Native North American": "Mixed",
    "Jewish and Caucasian; Scandinavian": "Mixed",
    "Kurdistani and Tunisian": "Mixed",
    "Latino and Native American": "Mixed",
    "Native South American and Hispanic": "Mixed",

    "Caucasian": "White",
    "Caucasian, not Hispanic": "White",
    "Caucasian; Albanian": "White",
    "Caucasian; Amish": "White",
    "Caucasian; Armenian": "White",
    "Caucasian; Austrian": "White",
    "Caucasian; Belgian": "White",
    "Caucasian; British": "White",
    "Caucasian; Bulgarian": "White",
    "Caucasian; Canadian Dariusleut Hutterite": "White",
    "Caucasian; Czechoslovakian": "White",
    "Caucasian; Danish": "White",
    "Caucasian; Dutch": "White",
    "Caucasian; English": "White",
    "Caucasian; Finnish": "White",
    "Caucasian; French": "White",
    "Caucasian; French/Italian": "White",
    "Caucasian; German": "White",
    "Caucasian; German/Irish": "White",
    "Caucasian; German/Swedish": "White",
    "Caucasian; Greek": "White",
    "Caucasian; Greek-Cypriot": "White",
    "Caucasian; Irish": "White",
    "Caucasian; Irish/Italian": "White",
    "Caucasian; Italian": "White",
    "Caucasian; Mennonite": "White",
    "Caucasian; Non-hispanic white": "White",
    "Caucasian; Norwegian": "White",
    "Caucasian; Polish": "White",
    "Caucasian; Portuguese": "White",
    "Caucasian; Romani": "White",
    "Caucasian; Russian": "White",
    "Caucasian; Sardinian": "White",
    "Caucasian; Scandinavian": "White",
    "Caucasian; Scottish": "White",
    "Caucasian; Siberian": "White",
    "Caucasian; Spanish": "White",
    "Jewish": "White",
    "Jewish; Ashkenazi": "White",

    "Jewish; Libyan": "Middle Eastern or North African",
    "Jewish; Yemenite": "Middle Eastern or North African",

    "African": "Black or African American",
    "African American": "Black or African American",
    "Black or African American": "Black or African American",
    "African; Angolan": "Black or African American",
    "African; Somali": "Black or African American",
    "African; Sudanese": "Black or African American",
    "African; Yoruba in Ibadan, Nigeria (YRI)": "Black or African American",
    "Afro-Brazilian": "Black or African American",
    "Lybian": "Black or African American", # check
    "Moroccan": "Black or African American", # check
    "Cape Verdian": "Black or African American", # check

    "Brazilian": "Hispanic or Latino",
    "Caribbean": "Hispanic or Latino",
    "Caribbean; Haitian": "Hispanic or Latino",
    "Chilean": "Hispanic or Latino",
    "Cuban": "Hispanic or Latino",
    "Hispanic": "Hispanic or Latino",
    "Latino": "Hispanic or Latino",
    "Latino or Hispanic": "Hispanic or Latino",
    "Latino or Hispanic; Dominican": "Hispanic or Latino",
    "Mexican": "Hispanic or Latino",
    "Puerto Rican": "Hispanic or Latino",
    "South American (Brazil, Guyana, Venezuela)": "Hispanic or Latino",

    "Native American": "American Indian or Alaska Native",
    "Native Central American; Pima": "American Indian or Alaska Native",
    "Native North American": "American Indian or Alaska Native",
    "Native North American; Alaskan": "American Indian or Alaska Native",
    "Native North American; Cherokee": "American Indian or Alaska Native",
    "Pacific": "Native Hawaiian or Other Pacific Islander",
    "Aboriginal Australian": "Native Hawaiian or Other Pacific Islander",

    "Asian": "Asian",
    "Afghanistan; Persian": "Asian",
    "Bangladeshi": "Asian",
    "Bengali": "Asian",
    "Chinese": "Asian",
    "Chinese; Han": "Asian",
    "Chinese; Malaysian": "Asian",
    "Chinese; Singaporian": "Asian",
    "Chinese; Taiwan": "Asian",
    "Chinese/Asian ethnic group: Hui": "Asian",
    "Chinese/Asian ethnic group: Uyghur": "Asian",
    "East Asian": "Asian",
    "East Indian": "Asian",
    "Indian": "Asian",
    "Japanese": "Asian",
    "Japanese and Korean": "Asian",
    "Kazakh": "Asian",
    "Korean": "Asian",
    "Mongolian": "Asian",
    "Nepali": "Asian",
    "Pakistani": "Asian",
    "Ryukyuan": "Asian",
    "South Asian": "Asian",
    "Southeast Asian": "Asian",
    "Southeast Asian; Burmese": "Asian",
    "Southeast Asian; Cambodian": "Asian",
    "Southeast Asian; Filipino": "Asian",
    "Southeast Asian; Thai": "Asian",
    "Southeast Asian; Vietnamese": "Asian",

    "Unknown": "Unknown",

    "Middle Eastern": "Middle Eastern or North African",
    "Arab": "Middle Eastern or North African",
    "Arab; Qatari": "Middle Eastern or North African",
    "Bedouin": "Middle Eastern or North African",
    "Egyptian": "Middle Eastern or North African",
    "Iranian": "Middle Eastern or North African",
    "Iranian; Persian": "Middle Eastern or North African",
    "Iraqi": "Middle Eastern or North African",
    "Israeli": "Middle Eastern or North African",
    "Jewish; Libyan": "Middle Eastern or North African",
    "Jewish; Yemenite": "Middle Eastern or North African",
    "Jordanian": "Middle Eastern or North African",
    "Lebanese": "Middle Eastern or North African",
    "Palestinian": "Middle Eastern or North African",
    "Saudi Arabian": "Middle Eastern or North African",
    "Tunisian": "Middle Eastern or North African",
    "Turkish": "Middle Eastern or North African"
}

# %%
# Map geographical groups
df['Race and/or Ethnicity'] = df['CC_Population'].map(ethnicity_to_category)

# Group by geographical group and sum the counts
count_table = df.groupby('Race and/or Ethnicity')['count'].sum().reset_index().sort_values(by='count', ascending=False)

print(count_table)
# Out:
#                        Race and/or Ethnicity  count
# 7                                    Unknown  11933
# 8                                      White   6042
# 1                                      Asian   2547
# 2                  Black or African American    520
# 3                         Hispanic or Latino    281
# 4            Middle Eastern or North African    243
# 5                                      Mixed     75
# 6  Native Hawaiian or Other Pacific Islander     15
# 0           American Indian or Alaska Native     14
